# %% [markdown]
# # Data Input and Output with Pandas
#
# Pandas provides powerful tools for reading and writing data in various formats. Let's explore the most common methods.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV Files
#
# ### CSV Input

# %%
df = pd.read_csv('example.csv')
df.head()
# Out:
#    Row No  Order Code  Order Date   Ship Date   Delivery Mode  Client ID  \
# 0       1  ORD-300774  03/02/2021  01/04/2020     First Class  CID-87591
# 1       2  ORD-600409  05/07/2020  01/04/2020    Second Class  CID-62245
# 2       3  ORD-457246  10/08/2021  01/04/2020    Second Class  CID-17857
# 3       4  ORD-106157  05/14/2021  01/06/2020    Second Class  CID-69708
# 4       5  ORD-369570  07/09/2021  01/05/2020  Standard Class  CID-86540
#
#      Client Name Category Type         Country         City  ... Postal Code  \
# 0  Michael Smith   Home Office   United States     New York  ...       62424
# 1     Emma Brown   Home Office          Canada  Los Angeles  ...       20315
# 2  Robert Taylor   Home Office   United States     New York  ...       22852
# 3     Emma Brown   Home Office  United Kingdom  Los Angeles  ...       14912
# 4   James Wilson   Home Office  United Kingdom       London  ...       19438
#
#     Region   Item Code Product Category Product Type  \
# 0    North  ITM-567743  Office Supplies      Binders
# 1  Central  ITM-224900      Electronics      Binders
# 2    North  ITM-135683        Furniture        Paper
# 3    North  ITM-947921      Electronics      Storage
# 4    North  ITM-330322      Electronics      Binders
#
#                  Product Title Sale Price  Units Sold  Discount Rate  \
# 0               Filing Cabinet     476.92           1           0.10
# 1  Noise Cancelling Headphones     438.01           8           0.33
# 2                 Office Paper     960.73           1           0.09
# 3                 Smartphone X     811.60           9           0.34
# 4            Wireless Keyboard    1253.69           4           0.47
#
#    Net Profit
# 0      -98.42
# 1      467.05
# 2      -20.73
# 3     -175.79
# 4     -431.21
#
# [5 rows x 21 columns]

# %% [markdown]
# ### CSV Output

# %%
#let's do some modification on the df and save it as a new df 
df['Total Revenue'] = df['Sale Price'] * df['Units Sold']  # Add new column
df['Profit Margin'] = df['Net Profit'] / df['Total Revenue']  # Add another column
df['Order Year'] = pd.to_datetime(df['Order Date']).dt.year  # Extract year from Order Date

# Save to new CSV
df.to_csv('modified_sales_data.csv', index=False)

# %% [markdown]
# ## Excel Files
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
pd.read_excel('excel_example.xlsx')
# Out:
#      Row No  Order Code  Order Date   Ship Date   Delivery Mode  Client ID  \
# 0         1  ORD-300774  03/02/2021  01/04/2020     First Class  CID-87591
# 1         2  ORD-600409  05/07/2020  01/04/2020    Second Class  CID-62245
# 2         3  ORD-457246  10/08/2021  01/04/2020    Second Class  CID-17857
# 3         4  ORD-106157  05/14/2021  01/06/2020    Second Class  CID-69708
# 4         5  ORD-369570  07/09/2021  01/05/2020  Standard Class  CID-86540
# ..      ...         ...         ...         ...             ...        ...
# 495     496  ORD-873689  06/07/2021  01/10/2020        Same Day  CID-95729
# 496     497  ORD-756397  08/16/2020  01/04/2020        Same Day  CID-95965
# 497     498  ORD-909740  06/21/2020  01/06/2020    Second Class  CID-30373
# 498     499  ORD-801693  09/23/2020  01/05/2020    Second Class  CID-13147
# 499     500  ORD-947134  06/11/2020  01/05/2020        Same Day  CID-28945
#
#        Client Name Category Type         Country         City  ...  \
# 0    Michael Smith   Home Office   United States     New York  ...
# 1       Emma Brown   Home Office          Canada  Los Angeles  ...
# 2    Robert Taylor   Home Office   United States     New York  ...
# 3       Emma Brown   Home Office  United Kingdom  Los Angeles  ...
# 4     James Wilson   Home Office  United Kingdom       London  ...
# ..             ...           ...             ...          ...  ...
# 495  Robert Taylor     Corporate          Canada     New York  ...
# 496     Emma Brown   Home Office   United States  Los Angeles  ...
# 497   Olivia Davis      Consumer          Canada      Phoenix  ...
# 498  Michael Smith      Consumer   United States      Houston  ...
# 499     Emma Brown   Home Office  United Kingdom      Toronto  ...
#
#     Postal Code   Region   Item Code Product Category Product Type  \
# 0         62424    North  ITM-567743  Office Supplies      Binders
# 1         20315  Central  ITM-224900      Electronics      Binders
# 2         22852    North  ITM-135683        Furniture        Paper
# 3         14912    North  ITM-947921      Electronics      Storage
# 4         19438    North  ITM-330322      Electronics      Binders
# ..          ...      ...         ...              ...          ...
# 495       25499     West  ITM-714005        Furniture   Appliances
# 496       55766    South  ITM-797959  Office Supplies      Storage
# 497       75088     East  ITM-243038        Furniture        Paper
# 498       40273    South  ITM-938918        Furniture       Phones
# 499       51235    South  ITM-790084        Furniture  Furnishings
#
#                    Product Title Sale Price  Units Sold  Discount Rate  \
# 0                 Filing Cabinet     476.92           1           0.10
# 1    Noise Cancelling Headphones     438.01           8           0.33
# 2                   Office Paper     960.73           1           0.09
# 3                   Smartphone X     811.60           9           0.34
# 4              Wireless Keyboard    1253.69           4           0.47
# ..                           ...        ...         ...            ...
# 495                Laser Printer    1373.23           5           0.41
# 496            Wireless Keyboard     772.73           1           0.49
# 497  Noise Cancelling Headphones    1214.32           7           0.30
# 498            Wireless Keyboard     807.98           5           0.03
# 499               Executive Desk     592.84           8           0.41
#
#      Net Profit
# 0        -98.42
# 1        467.05
# 2        -20.73
# 3       -175.79
# 4       -431.21
# ..          ...
# 495       30.28
# 496       -8.46
# 497     -280.60
# 498       62.99
# 499     -440.70
#
# [500 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Row No', 'Order Code', 'Order Date', 'Ship Date', 'Delivery Mode',
#        'Client ID', 'Client Name', 'Category Type', 'Country', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Item Code',
#        'Product Category', 'Product Type', 'Product Title', 'Sale Price',
#        'Units Sold', 'Discount Rate', 'Net Profit', 'Total Revenue',
#        'Profit Margin', 'Order Year'],
#       dtype='object')

# %% [markdown]
# ### Excel Output

# %%
revenue=df['Total Revenue']
profit=df['Net Profit']
# Create Excel writer
with pd.ExcelWriter('financial_reports.xlsx') as writer:
    revenue.to_excel(writer, sheet_name='Total Revenue')
    profit.to_excel(writer, sheet_name='Net Profit')

# %% [markdown]
# ## Working with HTML Tables in Pandas
#
# ### Required Packages
# To parse HTML tables in Pandas, ensure these packages are installed:
#
# - **`lxml`** (fast HTML/XML parser)
# - **`html5lib`** (backup parser for complex HTML)
# - **`BeautifulSoup4`** (optional but useful for scraping)
#
# ---
#
# ### Installation Instructions
#
# #### **Option 1: Anaconda (Recommended)**
# Run in **terminal/command prompt**:
# ```bash
# conda install lxml html5lib beautifulsoup4
# ```
# **Restart Jupyter Notebook** afterward.
#
# #### **Option 2: pip (Non-Anaconda Users)**
# ```bash
# pip install lxml html5lib beautifulsoup4
# ```
#
# ---
#
# ### Example: Reading HTML Tables
# Pandas can extract tables directly from HTML (e.g., websites or local files):
#
# ```python
# import pandas as pd
#
# # Read tables from a URL
# url = "https://example.com/data.html"
# tables = pd.read_html(url)  # Returns a list of DataFrames
#
# # Display the first table
# tables[0].head()
# ```
#
# > **Note**:
# > - `lxml` is the default parser (fastest).
# > - `html5lib` handles malformed HTML but is slower.
# > - `BeautifulSoup4` is used internally by Pandas for parsing.

# %% [markdown]
# **Wikipedia List of Countries: Contains clean tables with country names and populations.**

# %%
df1 = pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)")

# %%
df1[0]
# Out:
#                   Country or territory  Population (1 July 2022)  \
# 0                                World                8021407192
# 1                                India                1425423212
# 2                             China[a]                1425179569
# 3                        United States                 341534046
# 4                            Indonesia                 278830529
# ..                                 ...                       ...
# 233        Montserrat (United Kingdom)                      4453
# 234  Falkland Islands (United Kingdom)                      3490
# 235              Tokelau (New Zealand)                      2290
# 236                 Niue (New Zealand)                      1821
# 237                    Vatican City[x]                       505
#
#      Population (1 July 2023) Change (%) UN continental region[1]  \
# 0                  8091734930     +0.88%                        –
# 1                  1438069596     +0.89%                     Asia
# 2                  1422584933     −0.18%                     Asia
# 3                   343477335     +0.57%                 Americas
# 4                   281190067     +0.85%                     Asia
# ..                        ...        ...                      ...
# 233                      4420     −0.74%                 Americas
# 234                      3477     −0.37%                 Americas
# 235                      2397     +4.67%                  Oceania
# 236                      1817     −0.22%                  Oceania
# 237                       496     −1.78%                   Europe
#
#     UN statistical subregion[1]
# 0                             –
# 1                 Southern Asia
# 2                  Eastern Asia
# 3              Northern America
# 4            South-eastern Asia
# ..                          ...
# 233                   Caribbean
# 234               South America
# 235                   Polynesia
# 236                   Polynesia
# 237             Southern Europe
#
# [238 rows x 6 columns]

# %% [markdown]
# **Financial Data (NASDAQ Stocks): S&P 500 components table (useful for financial analysis).**

# %%
pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")[0]
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# 2                           Health Care Equipment  North Chicago, Illinois
# 3                                   Biotechnology  North Chicago, Illinois
# 4                  IT Consulting & Other Services          Dublin, Ireland
# ..                                            ...                      ...
# 498  Industrial Machinery & Supplies & Components   White Plains, New York
# 499                                   Restaurants     Louisville, Kentucky
# 500            Electronic Equipment & Instruments   Lincolnshire, Illinois
# 501                         Health Care Equipment          Warsaw, Indiana
# 502                               Pharmaceuticals   Parsippany, New Jersey
#
#      Date added      CIK      Founded
# 0    1957-03-04    66740         1902
# 1    2017-07-26    91142         1916
# 2    1957-03-04     1800         1888
# 3    2012-12-31  1551152  2013 (1888)
# 4    2011-07-06  1467373         1989
# ..          ...      ...          ...
# 498  2011-11-01  1524472         2011
# 499  1997-10-06  1041061         1997
# 500  2019-12-23   877212         1969
# 501  2001-08-07  1136869         1927
# 502  2013-06-21  1555280         1952
#
# [503 rows x 8 columns]

# %% [markdown]
# **Climate Data: CO₂ emissions by country (requires table index selection).**

# %%
pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_carbon_dioxide_emissions")[1]
# Out:
#     Fossil CO2 emissions 2023                Country/Territory/Region/Group  \
#                         ktCO2                Country/Territory/Region/Group
# 0                 13259638.95                                         China
# 1                  4682039.41                                 United States
# 2                  2955181.68                                         India
# 3                  2069502.01                                        Russia
# 4                   944758.61                                         Japan
# ..                        ...                                           ...
# 205                     19.45                              Falkland Islands
# 206                     17.77  Saint Helena, Ascension and Tristan da Cunha
# 207                      2.10                                 Faroe Islands
# 208               39023937.04                                  Global Total
# 209                   2512.07                                European Union
#
#     Fossil CO2 emissions per capita 2023
#                                     tCO2
# 0                                   9.24
# 1                                  13.83
# 2                                   2.07
# 3                                  14.45
# 4                                   7.54
# ..                                   ...
# 205                                 6.48
# 206                                 4.44
# 207                                 0.04
# 208                                 4.86
# 209                                 5.66
#
# [210 rows x 3 columns]
